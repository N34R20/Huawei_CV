# %% [markdown]
# **Exercise 1**: The purpose of this exercise is to use neural networks to learn a function y = f(x). You will be given a set of inputs x and outputs y. You will explore different networks as instructed below to see how each of them can capture (or not) the properties of the true underlying function.

# %%
# importing neccessasry libraries
import numpy as np
import torch.optim as optim
from matplotlib import pyplot as plt
import torch
import torch.nn as nn

# %%
# creating data for training

def func(x):
  return x**3 - 0.5 * x**2 - x + 1.5

x = np.linspace(-3, 3, 80)
y = func(x)

x_test =np.concatenate([np.linspace(3.1, 4, 10), np.linspace(-2.5, 2.5, 17)])
y_test = func(x_test)
x, x_test
# Out:
# (array([-3.        , -2.92405063, -2.84810127, -2.7721519 , -2.69620253,
#         -2.62025316, -2.5443038 , -2.46835443, -2.39240506, -2.3164557 ,
#         -2.24050633, -2.16455696, -2.08860759, -2.01265823, -1.93670886,
#         -1.86075949, -1.78481013, -1.70886076, -1.63291139, -1.55696203,
#         -1.48101266, -1.40506329, -1.32911392, -1.25316456, -1.17721519,
#         -1.10126582, -1.02531646, -0.94936709, -0.87341772, -0.79746835,
#         -0.72151899, -0.64556962, -0.56962025, -0.49367089, -0.41772152,
#         -0.34177215, -0.26582278, -0.18987342, -0.11392405, -0.03797468,
#          0.03797468,  0.11392405,  0.18987342,  0.26582278,  0.34177215,
#          0.41772152,  0.49367089,  0.56962025,  0.64556962,  0.72151899,
#          0.79746835,  0.87341772,  0.94936709,  1.02531646,  1.10126582,
#          1.17721519,  1.25316456,  1.32911392,  1.40506329,  1.48101266,
#          1.55696203,  1.63291139,  1.70886076,  1.78481013,  1.86075949,
#          1.93670886,  2.01265823,  2.08860759,  2.16455696,  2.24050633,
#          2.3164557 ,  2.39240506,  2.46835443,  2.5443038 ,  2.62025316,
#          2.69620253,  2.7721519 ,  2.84810127,  2.92405063,  3.        ]),
#  array([ 3.1   ,  3.2   ,  3.3   ,  3.4   ,  3.5   ,  3.6   ,  3.7   ,
#          3.8   ,  3.9   ,  4.    , -2.5   , -2.1875, -1.875 , -1.5625,
#         -1.25  , -0.9375, -0.625 , -0.3125,  0.    ,  0.3125,  0.625 ,
#          0.9375,  1.25  ,  1.5625,  1.875 ,  2.1875,  2.5   ]))

# %%
#@title Visualizing the ground truth training data
plt.figure()
plt.scatter(x, y)
plt.show()

# %%
#@title TODO: Define the neural networks

class NeuralNet_1Layer(nn.Module):
  def __init__(self):
    super(NeuralNet_1Layer, self).__init__()
    # TODO define 1 layer neural network
    self.linear = nn.Linear(1, 1)

  # TODO implement forward function
  def forward(self, x):
    out = self.linear(x)
    return out

class NeuralNet_2Layer(nn.Module):
  def __init__(self):
    super(NeuralNet_2Layer, self).__init__()
    # TODO define 2 layer neural network. Use 5 neurons for the hidden layer
    self.linear = nn.Linear(1, 5)
    self.linear2 = nn.Linear(5, 1)

  # TODO implement forward function
  def forward(self, x):
    out = self.linear2(self.linear(x))
    return out


class NeuralNet_2Layer_activation(nn.Module):
  def __init__(self):
    super(NeuralNet_2Layer_activation, self).__init__()
    # TODO define 2 layer neural network with an activation between the layers
    # choose between common activation functions from the lecture, e.g. sigmoid, relu
    # Also here use 5 neurons for the hidden layer
    self.linear = nn.Linear(1, 5)
    self.relu = nn.ReLU()
    self.linear2 = nn.Linear(5, 1)

  # TODO implement forward function
  def forward(self, x):
    out = self.linear2(self.relu(self.linear(x)))
    return out

# %%
# convert input and output to torch tensors, so that we can feed them to a PyTorch network
x_tensor = torch.from_numpy(x).reshape(-1, 1).float()
y_tensor = torch.from_numpy(y).reshape(-1, 1).float()
x_test_tensor = torch.from_numpy(x_test).reshape(-1, 1).float()
y_test_tensor = torch.from_numpy(y_test).reshape(-1, 1).float()

# Hyper parameters
epochs = 500
batch_size = 20
learning_rate = 0.01

# initialize networks and set them to training mode
net1 = NeuralNet_1Layer().train()
net2 = NeuralNet_2Layer().train()
net3 = NeuralNet_2Layer_activation().train()

# TODO initialize an optimizer (e.g. SGD) of each net. Don't forget to pass the learning_rate as argument!
# Hint try reducing the learning rate if the loss fuction = nan for a certain model
optimizer1 = optim.SGD(net1.parameters(), lr=learning_rate )
optimizer2 = optim.SGD(net2.parameters(), lr=learning_rate )
optimizer3 = optim.SGD(net3.parameters(), lr=learning_rate )

def training_loop(net, optimizer, x_tensor, y_tensor, batch_size, epochs, x_test_tensor, y_test_tensor):
  # TODO implement the training loop. make sure it contains all the steps from the lecture!
  for epoch in range(epochs):
    for i in range(0,len(x_tensor),batch_size):

      # TODO reset the gradients to zero
      optimizer.zero_grad()

      # TODO get current data batch
      x_input = x_tensor[i:i+batch_size]
      y_gt = y_tensor[i:i+batch_size]

      # TODO get network prediction for input batch x_input
      y_predicted = net(x_input)

      # TODO implement a reasonable loss function of your choice. keep in mind, is this a regression or a classification task?
      loss = nn.MSELoss()(y_predicted, y_gt)

      # TODO compute the gradients
      optimizer.gradients = loss.backward()

      # TODO backpropagate the loss
      #loss.backward()

      # TODO call an optimization step
      optimizer.step()

    # TODO evaluate the network every 10 epochs
    if epoch % 10 == 0:
      y_predicted = net(x_tensor)
      error = nn.MSELoss()(y_predicted, y_tensor).item()
      print("Epoch=", epoch, "Error=", error)

  # setting the network to evaluate mode
  net.eval()

  # TODO compute the mean L2 error on the whole training set
  y_predicted = net(x_tensor)
  error = nn.MSELoss()(y_predicted, y_tensor)
  print("Final TRAIN error=", error)

  # TODO similarly compute the mean L2 error in the test set
  y_test_predicted = net(x_test_tensor)
  error = nn.MSELoss()(y_test_predicted, y_test_tensor)
  print("Final TEST error=", error)

  # converting the predictions to numpy so that we can visualize them
  y_pred = y_predicted.reshape(-1).detach().numpy()
  y_test_pred = y_test_predicted.reshape(-1).detach().numpy()

  # vizualize predictions and ground truth data for training and test set
  plt.figure()
  plt.scatter(x, y)
  plt.scatter(x, y_pred)
  plt.scatter(x_test, y_test)
  plt.scatter(x_test, y_test_pred)
  plt.show()

# call the training loop for each of your networks
print("Starting training for 1 layer NN")
training_loop(net1, optimizer1, x_tensor, y_tensor, batch_size, epochs, x_test_tensor, y_test_tensor)
print("Starting training for 2 layer NN")
training_loop(net2, optimizer2, x_tensor, y_tensor, batch_size, epochs, x_test_tensor, y_test_tensor)
print("Starting training for 2 layer NN with activation")
training_loop(net3, optimizer3, x_tensor, y_tensor, batch_size, epochs, x_test_tensor, y_test_tensor)
# Out:
# Starting training for 1 layer NN
# Epoch= 0 Error= 56.9976692199707
# Epoch= 10 Error= 20.077707290649414
# Epoch= 20 Error= 19.831676483154297
# Epoch= 30 Error= 19.823177337646484
# Epoch= 40 Error= 19.822185516357422
# Epoch= 50 Error= 19.822124481201172
# Epoch= 60 Error= 19.822162628173828
# Epoch= 70 Error= 19.82219123840332
# Epoch= 80 Error= 19.822206497192383
# Epoch= 90 Error= 19.82221221923828
# Epoch= 100 Error= 19.822216033935547
# Epoch= 110 Error= 19.82221794128418
# Epoch= 120 Error= 19.822216033935547
# Epoch= 130 Error= 19.822216033935547
# Epoch= 140 Error= 19.822216033935547
# Epoch= 150 Error= 19.82221794128418
# Epoch= 160 Error= 19.82221794128418
# Epoch= 170 Error= 19.82221794128418
# Epoch= 180 Error= 19.82221794128418
# Epoch= 190 Error= 19.82221794128418
# Epoch= 200 Error= 19.82221794128418
# Epoch= 210 Error= 19.82221794128418
# Epoch= 220 Error= 19.82221794128418
# Epoch= 230 Error= 19.82221794128418
# Epoch= 240 Error= 19.82221794128418
# Epoch= 250 Error= 19.82221794128418
# Epoch= 260 Error= 19.82221794128418
# Epoch= 270 Error= 19.82221794128418
# Epoch= 280 Error= 19.82221794128418
# Epoch= 290 Error= 19.82221794128418
# Epoch= 300 Error= 19.82221794128418
# Epoch= 310 Error= 19.82221794128418
# Epoch= 320 Error= 19.82221794128418
# Epoch= 330 Error= 19.82221794128418
# Epoch= 340 Error= 19.82221794128418
# Epoch= 350 Error= 19.82221794128418
# Epoch= 360 Error= 19.82221794128418
# Epoch= 370 Error= 19.82221794128418
# Epoch= 380 Error= 19.82221794128418
# Epoch= 390 Error= 19.82221794128418
# Epoch= 400 Error= 19.82221794128418
# Epoch= 410 Error= 19.82221794128418
# Epoch= 420 Error= 19.82221794128418
# Epoch= 430 Error= 19.82221794128418
# Epoch= 440 Error= 19.82221794128418
# Epoch= 450 Error= 19.82221794128418
# Epoch= 460 Error= 19.82221794128418
# Epoch= 470 Error= 19.82221794128418
# Epoch= 480 Error= 19.82221794128418
# Epoch= 490 Error= 19.82221794128418
# Final TRAIN error= tensor(19.8222, grad_fn=<MseLossBackward0>)
# Final TEST error= tensor(200.5162, grad_fn=<MseLossBackward0>)
# Starting training for 2 layer NN
# Epoch= 0 Error= 23.99444007873535
# Epoch= 10 Error= 20.003803253173828
# Epoch= 20 Error= 19.9962100982666
# Epoch= 30 Error= 19.98917007446289
# Epoch= 40 Error= 19.982343673706055
# Epoch= 50 Error= 19.975696563720703
# Epoch= 60 Error= 19.969242095947266
# Epoch= 70 Error= 19.96300506591797
# Epoch= 80 Error= 19.957012176513672
# Epoch= 90 Error= 19.951290130615234
# Epoch= 100 Error= 19.94585609436035
# Epoch= 110 Error= 19.940719604492188
# Epoch= 120 Error= 19.93589210510254
# Epoch= 130 Error= 19.93136978149414
# Epoch= 140 Error= 19.927160263061523
# Epoch= 150 Error= 19.923259735107422
# Epoch= 160 Error= 19.919660568237305
# Epoch= 170 Error= 19.916362762451172
# Epoch= 180 Error= 19.91335678100586
# Epoch= 190 Error= 19.91063117980957
# Epoch= 200 Error= 19.908180236816406
# Epoch= 210 Error= 19.90599250793457
# Epoch= 220 Error= 19.904056549072266
# Epoch= 230 Error= 19.902362823486328
# Epoch= 240 Error= 19.900896072387695
# Epoch= 250 Error= 19.89964485168457
# Epoch= 260 Error= 19.898601531982422
# Epoch= 270 Error= 19.897747039794922
# Epoch= 280 Error= 19.897071838378906
# Epoch= 290 Error= 19.896568298339844
# Epoch= 300 Error= 19.896223068237305
# Epoch= 310 Error= 19.89602279663086
# Epoch= 320 Error= 19.895959854125977
# Epoch= 330 Error= 19.89602279663086
# Epoch= 340 Error= 19.896194458007812
# Epoch= 350 Error= 19.8964786529541
# Epoch= 360 Error= 19.8968563079834
# Epoch= 370 Error= 19.897319793701172
# Epoch= 380 Error= 19.897863388061523
# Epoch= 390 Error= 19.898487091064453
# Epoch= 400 Error= 19.899166107177734
# Epoch= 410 Error= 19.899911880493164
# Epoch= 420 Error= 19.90070343017578
# Epoch= 430 Error= 19.90154457092285
# Epoch= 440 Error= 19.902423858642578
# Epoch= 450 Error= 19.90334701538086
# Epoch= 460 Error= 19.9042911529541
# Epoch= 470 Error= 19.905269622802734
# Epoch= 480 Error= 19.906267166137695
# Epoch= 490 Error= 19.90728759765625
# Final TRAIN error= tensor(19.9082, grad_fn=<MseLossBackward0>)
# Final TEST error= tensor(191.7538, grad_fn=<MseLossBackward0>)
# Starting training for 2 layer NN with activation
# Epoch= 0 Error= 69.2043685913086
# Epoch= 10 Error= 20.40369415283203
# Epoch= 20 Error= 14.192453384399414
# Epoch= 30 Error= 9.912684440612793
# Epoch= 40 Error= 7.339257717132568
# Epoch= 50 Error= 5.708469390869141
# Epoch= 60 Error= 11.892104148864746
# Epoch= 70 Error= 4.555822849273682
# Epoch= 80 Error= 8.779838562011719
# Epoch= 90 Error= 4.840447902679443
# Epoch= 100 Error= 3.749741792678833
# Epoch= 110 Error= 4.966837406158447
# Epoch= 120 Error= 4.266453742980957
# Epoch= 130 Error= 6.176339626312256
# Epoch= 140 Error= 4.137640476226807
# Epoch= 150 Error= 4.117242813110352
# Epoch= 160 Error= 3.4384665489196777
# Epoch= 170 Error= 3.506077289581299
# Epoch= 180 Error= 3.4534897804260254
# Epoch= 190 Error= 3.3321986198425293
# Epoch= 200 Error= 3.228900194168091
# Epoch= 210 Error= 2.8596980571746826
# Epoch= 220 Error= 2.5637118816375732
# Epoch= 230 Error= 2.2978227138519287
# Epoch= 240 Error= 2.504767656326294
# Epoch= 250 Error= 2.610250473022461
# Epoch= 260 Error= 2.6476566791534424
# Epoch= 270 Error= 2.231566905975342
# Epoch= 280 Error= 2.0134823322296143
# Epoch= 290 Error= 2.09273362159729
# Epoch= 300 Error= 2.3341777324676514
# Epoch= 310 Error= 2.1316657066345215
# Epoch= 320 Error= 1.8196367025375366
# Epoch= 330 Error= 1.7767667770385742
# Epoch= 340 Error= 1.8994972705841064
# Epoch= 350 Error= 2.050936222076416
# Epoch= 360 Error= 1.9727790355682373
# Epoch= 370 Error= 1.7121225595474243
# Epoch= 380 Error= 1.4965307712554932
# Epoch= 390 Error= 1.4152921438217163
# Epoch= 400 Error= 1.1792147159576416
# Epoch= 410 Error= 1.1186399459838867
# Epoch= 420 Error= 1.3585078716278076
# Epoch= 430 Error= 1.6672790050506592
# Epoch= 440 Error= 1.7243707180023193
# Epoch= 450 Error= 1.4602463245391846
# Epoch= 460 Error= 1.252335786819458
# Epoch= 470 Error= 1.2047933340072632
# Epoch= 480 Error= 1.299468755722046
# Epoch= 490 Error= 1.3763134479522705
# Final TRAIN error= tensor(1.3001, grad_fn=<MseLossBackward0>)
# Final TEST error= tensor(49.1561, grad_fn=<MseLossBackward0>)

# %% [markdown]
# **TODO** write a short comment about your result observation
# Which of the networks is able to capture non-linearities?
# What can you say about the general ability of neural netwoks to
# * interpolate - i.e. accuracy of test samples in between training samples
# and
# * extrapolate - i.e. accuracy of test samples outside of training disctribution ?

# %%
# I did hope that the Net 3 with the activation function turned out to capture some non-linearity and it was the case.
# for the iterpolation in the first 10 epochs all the nets already arrives at the lowest error in the training
# for the extrapolation the first network was the one that has lower error and it's the simplest one of the three
